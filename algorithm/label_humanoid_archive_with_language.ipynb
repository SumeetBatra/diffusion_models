# %%
import os
from pathlib import Path
project_root = os.path.join(str(Path.home()), 'diffusion_models')
os.chdir(project_root)
# %pwd # should be PPGA root dir

# %%
import pickle
import torch
import numpy as np

from autoencoders.policy.resnet3d import ResNet3DAutoEncoder
from autoencoders.policy.hypernet import HypernetAutoEncoder
from attrdict import AttrDict
from RL.actor_critic import Actor
from envs.brax_custom.brax_env import make_vec_env_brax
from IPython.display import HTML, Image
from IPython.display import display
from brax.io import html, image
from dataset.tensor_elites_dataset import preprocess_model, postprocess_model
from utils.brax_utils import shared_params
from tqdm import tqdm
import glob
from utils.normalize import ObsNormalizer
import json

# %%
# params to config
device = torch.device('cuda')
env_name = 'humanoid'
seed = 1111
normalize_obs = True
normalize_rewards = True
obs_shape = shared_params[env_name]['obs_dim']
action_shape = shared_params[env_name]['action_dim']
mlp_shape = (128, 128, action_shape)

env_cfg = AttrDict({
    'env_name': env_name,
    'env_batch_size': None,
    'num_dims': 2,
    'seed': seed,
    'num_envs': 1,
    'clip_obs_rew': True,
})

# %%
print(glob.glob(f'data/{env_name}/*.pkl'))
archive_df_path = f'data/{env_name}/archive100x100.pkl'
with open(archive_df_path, 'rb') as f:
    archive_df = pickle.load(f)

# %%
# make the env
env = make_vec_env_brax(env_cfg)

# %%
def integrate_obs_normalizer(agent: Actor):
    assert agent.obs_normalizer is not None
    w_in = agent.actor_mean[0].weight.data
    b_in = agent.actor_mean[0].bias.data
    mean, var = agent.obs_normalizer.obs_rms.mean, agent.obs_normalizer.obs_rms.var
    w_new = w_in / torch.sqrt(var + 1e-8)
    b_new = b_in - (mean / torch.sqrt(var + 1e-8)) @ w_in.T
    agent.actor_mean[0].weight.data = w_new
    agent.actor_mean[0].bias.data = b_new
    return agent

# %%
def enjoy_brax(agent, render=True, deterministic=True, normalize_obs=False):
    if normalize_obs:
        obs_mean, obs_var = agent.obs_normalizer.obs_rms.mean, agent.obs_normalizer.obs_rms.var
#         print(f'{obs_mean=}, {obs_var=}')

    obs = env.reset()
    rollout = [env.unwrapped._state]
    total_reward = 0
    measures = torch.zeros(env_cfg.num_dims).to(device)
    done = False
    while not done:
        with torch.no_grad():
            obs = obs.unsqueeze(dim=0).to(device)
            if normalize_obs:
                obs = (obs - obs_mean) / torch.sqrt(obs_var + 1e-8)

            if deterministic:
                act = agent.actor_mean(obs)
            else:
                act, _, _ = agent.get_action(obs)
            act = act.squeeze()
            obs, rew, done, info = env.step(act.cpu())
            measures += info['measures']
            rollout.append(env.unwrapped._state)
            total_reward += rew
    if render:
        i = HTML(html.render(env.unwrapped._env.sys, [s.qp for s in rollout]))
        display(i)
    print(f'{total_reward=}')
    print(f' Rollout length: {len(rollout)}')
    measures /= len(rollout)
    print(f'Measures: {measures.cpu().numpy()}')
    return total_reward.detach().cpu().numpy(), measures.cpu().numpy()

# %%
elites_array = archive_df.filter(regex='solution*').to_numpy()
metadata_list = archive_df.filter(regex='metadata*').to_numpy()
labels = []
inferred_labels = []
label_distances = []

# %%
len(elites_array)

# %% [markdown]
# ## Rerun next two / three cells until sufficiently labelled

# %%
# Render one elite
if len(label_distances) > 10:
    # If we have distances, use the elite with the largest distance
    elite_index = np.argmax(label_distances)
    print("elite distance to nearest label", np.max(label_distances))
    print("current label:", inferred_labels[elite_index][-1])
else:
    # Otherwise, use a random elite
    elite_index = np.random.randint(len(elites_array))
print('Elite index:', elite_index)
agent = Actor(obs_shape, action_shape, True, True).deserialize(elites_array[elite_index]).to(device)
obs_normalizer = ObsNormalizer(obs_shape).to(device)
obs_normalizer.load_state_dict(metadata_list[elite_index][0]['obs_normalizer'])
agent.obs_normalizer = obs_normalizer
# make sure pre and post-processing are working correctly. This should return
# the exact same agent as the previous line
# agent = postprocess_model(agent, preprocess_model(agent, mlp_shape), mlp_shape, deterministic=False).to(device)
# if normalize_obs:
#     agent = integrate_obs_normalizer(agent)
reward, measures = enjoy_brax(agent, render=True, normalize_obs=True)

# %%
# Add a new label
labels.append([float(reward), measures.tolist(), int(elite_index),
              "hop forward on your left foot while lifting your right foot"]) # REPLACE LABEL HERE
with open(f"data/{env_name}/text_labels_{len(labels):05d}.json", "w") as f:
    json.dump(labels, f, indent=True)
if label_distances:
    label_distances[elite_index] = 0.0
print(len(labels))
labels[-1]

# %%
# Recompute inferred labels
labelled_elites = np.array([elites_array[elite_index] for (returns, measures, elite_index, label) in labels])
labelled_elites_labels = [label for (returns, measures, elite_index, label) in labels]

def nearest_labelled_elite(archive_index):
    distances = ((labelled_elites - elites_array[archive_index]) ** 2).sum(axis=-1)
    return int(np.argmin(distances)), float(distances.min())

inferred_labels = []
label_distances = []
for archive_index in tqdm(range(len(elites_array))):
    inferred_label, label_dist = nearest_labelled_elite(archive_index)
    inferred_labels.append(labels[inferred_label])
    label_distances.append(label_dist)

# %%
with open(f"data/{env_name}/text_labels_{len(labels):05d}.pkl", "wb") as f:
    pickle.dump(inferred_labels, f)

# %%
import glob
sorted(glob.glob(f"data/{env_name}/text_labels_*.pkl"))

# %%
labels[-1][-1]

# %%
[label for label in labels]
# Out:
# [[9686.7509765625,
#   [0.08891108632087708, 0.39960038661956787],
#   2382,
#   'quickly slide forward on right foot'],
#  [340.4988098144531,
#   [0.03846153989434242, 0.9615384936332703],
#   5733,
#   'plant right foot and fall'],
#  [9545.927734375,
#   [0.8031967878341675, 0.5234764814376831],
#   4753,
#   'quickly walk forward while dragging right foot'],
#  [9687.6181640625,
#   [0.568431556224823, 0.27272725105285645],
#   483,
#   'quickly run forward using only your left foot'],
#  [9704.373046875,
#   [0.4865134656429291, 0.009990009479224682],
#   1107,
#   'quickly run forward while holding your right foot off the ground'],
#  [9644.732421875,
#   [0.4205794036388397, 0.5034964680671692],
#   3551,
#   'quickly walk forward while dragging your right foot'],
#  [9685.0009765625,
#   [0.3306693136692047, 0.29270729422569275],
#   1754,
#   'quickly run forward while leaning left'],
#  [9362.5634765625,
#   [0.8691308498382568, 0.6183816194534302],
#   6133,
#   'quickly shuffle forward while dragging your right foot'],
#  [9643.1162109375,
#   [0.48351648449897766, 0.3526473343372345],
#   1715,
#   'quickly walk forward'],
#  [9602.359375,
#   [0.4375624358654022, 0.11288710683584213],
#   1076,
#   'quickly walk forward while holding right foot up'],
#  [9576.564453125,
#   [0.7022976875305176, 0.615384578704834],
#   4409,
#   'quickly shuffle forward'],
#  [9501.97265625,
#   [0.923076868057251, 0.21178820729255676],
#   6451,
#   'quickly shuffle forward on your left foot'],
#  [9414.2119140625,
#   [0.919080913066864, 0.5444555282592773],
#   7255,
#   'quickly shuffle forward dragging your right foot'],
#  [1842.4737548828125,
#   [0.0, 0.6876640319824219],
#   5602,
#   'slowly hop forwards on your right foot then fall'],
#  [9617.923828125,
#   [0.3816183805465698, 0.7562437057495117],
#   6958,
#   'quickly run forwards favoring your left foot'],
#  [9728.7763671875,
#   [0.3436563313007355, 0.001998001942411065],
#   1141,
#   'quickly hop forwards on your left foot while holding up your right foot'],
#  [9614.818359375,
#   [0.7382616996765137, 0.0],
#   1402,
#   'quickly run forwards on your left foot while holding up your right foot'],
#  [77.80081939697266,
#   [0.10526315867900848, 0.0],
#   1459,
#   'immediately hop in place'],
#  [9316.2119140625,
#   [0.21978020668029785, 0.0009990009712055326],
#   1525,
#   'leap forwards on left foot while holding right foot off the ground'],
#  [9754.8916015625,
#   [0.24475523829460144, 0.0],
#   1450,
#   'quickly run forwards on your left foot while holding up your right foot'],
#  [604.4609985351562,
#   [0.0, 0.9722222089767456],
#   5569,
#   'balance in place on right foot then fall'],
#  [832.7098388671875,
#   [0.1666666716337204, 0.32500001788139343],
#   3799,
#   'slowly hop forward and fall'],
#  [82.66402435302734,
#   [0.1428571492433548, 0.0476190485060215],
#   2541,
#   'hop in place'],
#  [75.79632568359375, [0.0, 0.0], 3520, 'hop in place'],
#  [9685.197265625,
#   [0.25974026322364807, 0.6923076510429382],
#   3998,
#   'quickly run forward while dragging your right foot'],
#  [9670.6103515625,
#   [0.2237762212753296, 0.6993007063865662],
#   3038,
#   'skip forwards on your right foot'],
#  [9737.123046875,
#   [0.3136863112449646, 0.279720276594162],
#   1660,
#   'run forward while dragging your right foot'],
#  [476.5052795410156,
#   [0.7850466966629028, 0.7850466966629028],
#   4617,
#   'lunge in place and fall'],
#  [581.33056640625,
#   [0.10067114233970642, 0.9798657894134521],
#   5433,
#   'balance in place on right foot then fall'],
#  [9707.59765625,
#   [0.4615384340286255, 0.0009990009712055326],
#   1099,
#   'quickly run forwards on your left foot while holding up your right foot'],
#  [425.7570495605469,
#   [0.6421052813529968, 0.9157894849777222],
#   4630,
#   'lunge in place with with left foot then fall'],
#  [9627.5205078125,
#   [0.4645354449748993, 0.05794205516576767],
#   1110,
#   'run forward on left foot while holding right foot up'],
#  [9693.4931640625,
#   [0.4825174808502197, 0.1288711279630661],
#   487,
#   'run forward on left foot while holding right foot up'],
#  [9706.6396484375,
#   [0.6263735890388489, 0.042957041412591934],
#   626,
#   'run forward on left foot while holding right foot up'],
#  [77.6744613647461, [0.10000000149011612, 0.0], 2546, 'hop in place'],
#  [78.07392883300781, [0.10000000149011612, 0.0], 1456, 'hop in place'],
#  [700.4746704101562,
#   [0.044025156646966934, 0.9496855139732361],
#   5461,
#   'balance in place on right foot while lifting left foot then fall'],
#  [1145.7105712890625,
#   [0.022727273404598236, 0.875],
#   5463,
#   'shuffle forward on right foot while lifting left foot then fall'],
#  [779.1200561523438,
#   [0.025641025975346565, 0.8653846383094788],
#   5326,
#   'shuffle forward on right foot while lifting left foot then fall'],
#  [435.4373779296875,
#   [0.017543859779834747, 0.9912281036376953],
#   5527,
#   'balance in place on right foot then fall'],
#  [9739.2841796875,
#   [0.3806193768978119, 0.0009990009712055326],
#   1083,
#   'quickly run forward on left foot while holding right foot up'],
#  [303.4635925292969,
#   [0.027027027681469917, 0.7702702879905701],
#   5465,
#   'immediately fall'],
#  [428.9458312988281,
#   [0.3140495717525482, 0.8016528487205505],
#   5454,
#   'stand in place then fall'],
#  [537.0189819335938,
#   [0.15328466892242432, 0.8029196858406067],
#   5486,
#   'balance on right foot in place then fall'],
#  [389.1384582519531,
#   [0.31481480598449707, 0.8055555820465088],
#   5476,
#   'balance on right foot in place then fall'],
#  [9636.939453125,
#   [0.24575424194335938, 0.32867130637168884],
#   2652,
#   'quickly run forward'],
#  [157.98399353027344, [0.0, 0.21739131212234497], 2074, 'jump left and fall'],
#  [2456.157470703125,
#   [0.2708933651447296, 0.037463974207639694],
#   3570,
#   'jump wildly on left foot'],
#  [9676.8330078125,
#   [0.21178820729255676, 0.3946053981781006],
#   3733,
#   'quickly run forwards favoring your left foot'],
#  [9648.845703125,
#   [0.23476523160934448, 0.360639363527298],
#   2632,
#   'quickly skip forwards on your right foot'],
#  [9707.3037109375,
#   [0.23376622796058655, 0.1428571343421936],
#   1727,
#   'quickly and wildly skip forwards'],
#  [9677.6015625,
#   [0.24575424194335938, 0.1568431556224823],
#   1682,
#   'quickly shuffle forward on right foot then skip on left foot'],
#  [328.2140808105469,
#   [0.03333333507180214, 0.9888889193534851],
#   5578,
#   'balance on right foot in place then fall'],
#  [248.32911682128906,
#   [0.0, 0.660714328289032],
#   5426,
#   'slide right foor forwards and fall backwards'],
#  [343.4578857421875,
#   [0.0, 0.8829786777496338],
#   5420,
#   'balance on right foot in place then fall'],
#  [8501.9609375,
#   [0.0, 0.37362635135650635],
#   1862,
#   'quickly shuffle forwards on right foot while holding up left foot'],
#  [280.47076416015625,
#   [0.0, 0.7619048357009888],
#   5401,
#   'balance on right foot while lifting left foot then fall'],
#  [306.898193359375,
#   [0.0, 0.5454545617103577],
#   3056,
#   'balance on right foot while lifting left foot then fall'],
#  [306.4865417480469,
#   [0.0, 0.6081081032752991],
#   3052,
#   'balance on right foot while lifting left foot then fall'],
#  [356.7264709472656,
#   [0.0, 0.8311688303947449],
#   5453,
#   'balance on right foot while lifting left foot then fall backwards'],
#  [9636.9697265625,
#   [0.33966031670570374, 0.12187811732292175],
#   1018,
#   'quickly walk forward while lifting right foot'],
#  [9685.47265625,
#   [0.35464534163475037, 0.07192806899547577],
#   1036,
#   'run forward while lifting right foot'],
#  [7684.0078125,
#   [0.12487512081861496, 0.7492507100105286],
#   3114,
#   'quickly shuffle forward on right foot while stabilizing with left foot'],
#  [9698.287109375,
#   [0.3556443452835083, 0.06493506580591202],
#   1029,
#   'run forward on left foot while lifting right foot'],
#  [9736.34765625,
#   [0.2997002899646759, 0.17582416534423828],
#   942,
#   'run forward while dragging your right foot'],
#  [179.29049682617188,
#   [0.16949152946472168, 0.6440678238868713],
#   5593,
#   'immediately spin torso wildly then fall'],
#  [9747.2490234375,
#   [0.30669328570365906, 0.14085914194583893],
#   974,
#   'run forward on left foot'],
#  [9666.58984375,
#   [0.3016982972621918, 0.2467532455921173],
#   921,
#   'run forward on left foot while dragging right foot'],
#  [9706.8486328125,
#   [0.29470527172088623, 0.22877122461795807],
#   934,
#   'run forward on left foot while dragging right foot'],
#  [8992.5439453125,
#   [0.30669328570365906, 0.8951048851013184],
#   5785,
#   'run forward on left foot while dragging right foot'],
#  [9262.9892578125,
#   [0.2577422559261322, 0.9290708899497986],
#   5784,
#   'run forward on left foot while dragging right foot'],
#  [9326.9677734375,
#   [0.25574424862861633, 0.9470528960227966],
#   5863,
#   'run forward on left foot while dragging right foot'],
#  [304.3376770019531,
#   [0.18292681872844696, 0.7195121645927429],
#   5557,
#   'balance in place on right foot then fall'],
#  [8705.0498046875,
#   [0.30969029664993286, 0.9260739088058472],
#   4925,
#   'walk forward with left foot while dragging right foot'],
#  [9421.0390625,
#   [0.2127872109413147, 0.9390609264373779],
#   5851,
#   'walk forward with left foot while dragging right foot'],
#  [9195.259765625,
#   [0.2127872109413147, 0.9200798869132996],
#   5904,
#   'skip forwards on right foot while kicking with left foot'],
#  [9634.2958984375,
#   [0.3586413562297821, 0.07192806899547577],
#   1025,
#   'quickly hop forwards on left foot while lifting right foot'],
#  [9428.31640625,
#   [0.2467532455921173, 0.9520479440689087],
#   5865,
#   'run forwards on left foot while dragging right foot'],
#  [9421.4375,
#   [0.24475523829460144, 0.9610389471054077],
#   5862,
#   'run forwards on left foot while dragging right foot'],
#  [9701.9736328125,
#   [0.40159839391708374, 0.0],
#   1084,
#   'quickly run forwards on your left foot while lifting your right foot'],
#  [9674.703125,
#   [0.4255744218826294, 0.09190808981657028],
#   1111,
#   'hop forwards on your left foot while lifting your right foot'],
#  [9696.6357421875,
#   [0.23376622796058655, 0.00699300691485405],
#   1528,
#   'quickly hop forwards on left foot while lifting right foot'],
#  [9709.271484375,
#   [0.37662336230278015, 0.12187811732292175],
#   1079,
#   'shuffle forward on right foot then hop forwards on left foot while lifting right foot'],
#  [9700.970703125,
#   [0.24175824224948883, 0.00699300691485405],
#   2519,
#   'wildly hop forward on left foot while lifting your right foot up'],
#  [9693.4541015625,
#   [0.24775223433971405, 0.00699300691485405],
#   1513,
#   'wildly hop forward on left foot while lifting your right foot up'],
#  [9698.3408203125,
#   [0.25374624133110046, 0.00699300691485405],
#   1531,
#   'hop forward on left foot while lifting right foot up'],
#  [9711.439453125,
#   [0.24475523829460144, 0.004995004739612341],
#   1530,
#   'wildly hop forward on left foot while lifting right foot up'],
#  [134.98388671875,
#   [0.0, 0.3333333432674408],
#   2247,
#   'hop in place on right foot'],
#  [9668.07421875,
#   [0.24275723099708557, 0.00699300691485405],
#   1569,
#   'hop forward wildly on left your left foot while holding up your right foot'],
#  [9635.5546875,
#   [0.26173824071884155, 0.25374624133110046],
#   1559,
#   'quickly shuffle forward'],
#  [9461.82421875,
#   [0.09190808981657028, 0.38761237263679504],
#   2395,
#   'quickly slide forward on your right foot while lifting your left foot forwards'],
#  [9668.4013671875,
#   [0.10689310729503632, 0.4485514461994171],
#   3837,
#   'quickly slide forward on your right foot'],
#  [9664.9404296875,
#   [0.26473525166511536, 0.20779220759868622],
#   1637,
#   'run forward'],
#  [9677.5234375,
#   [0.09690309315919876, 0.4085913896560669],
#   2404,
#   'quickly slide forward on right foot'],
#  [2718.362060546875,
#   [0.12352941185235977, 0.2705882489681244],
#   2145,
#   'wildly skip forwards'],
#  [9717.658203125,
#   [0.25274723768234253, 0.05494505167007446],
#   1725,
#   'quickly and wildly hop forward on left foot'],
#  [9042.1669921875,
#   [0.17282716929912567, 0.1958041936159134],
#   2039,
#   'wildly skip forwards'],
#  [9174.2197265625,
#   [0.1738261729478836, 0.1598401516675949],
#   3782,
#   'wildly hop forwards'],
#  [9716.05078125,
#   [0.19180819392204285, 0.26973026990890503],
#   1961,
#   'quickly slide forward on right foot then skip'],
#  [9728.3427734375,
#   [0.1848151832818985, 0.27072927355766296],
#   1761,
#   'quickly slide forward on right foot while kicking with left foot'],
#  [9698.3876953125,
#   [0.20579420030117035, 0.5364634990692139],
#   2705,
#   'run forward while dragging right foot'],
#  [9737.8583984375,
#   [0.21378621459007263, 0.23976023495197296],
#   1601,
#   'run forward'],
#  [3728.58154296875,
#   [0.10059171915054321, 0.4595660865306854],
#   2440,
#   'slide forward on right foot then stumble and fall'],
#  [9735.6025390625,
#   [0.1908091902732849, 0.279720276594162],
#   1959,
#   'slide forward on right foot then skip'],
#  [2719.38671875,
#   [0.08439897745847702, 0.5242966413497925],
#   1602,
#   'slide forward on right foot while lifting left foot then fall'],
#  [9703.9208984375,
#   [0.21378621459007263, 0.4115884006023407],
#   2728,
#   'slide forward on right foot while kicking with your left foot'],
#  [9746.0078125,
#   [0.18581418693065643, 0.2577422559261322],
#   1968,
#   'skip forward and run forward'],
#  [1917.8052978515625,
#   [0.020066889002919197, 0.6421404480934143],
#   2439,
#   'slide forward on right foot then stop and fall'],
#  [9499.609375,
#   [0.804195761680603, 0.24775223433971405],
#   645,
#   'walk forward while dragging right foot'],
#  [2163.35009765625,
#   [0.652996838092804, 0.27760252356529236],
#   7254,
#   'walk forward slowly then trip and fall'],
#  [9639.59375,
#   [0.5414585471153259, 0.0839160829782486],
#   499,
#   'walk forward on left foot while keeping your right foot off the ground'],
#  [9617.951171875,
#   [0.5624375343322754, 0.060939058661460876],
#   1211,
#   'hop forward on your left foot while lifting your right foot off the ground'],
#  [9687.119140625,
#   [0.36563435196876526, 0.030969029292464256],
#   1035,
#   'hop forward on your left foot while lifting your right foot behind you'],
#  [9666.126953125,
#   [0.1568431556224823, 0.4815184772014618],
#   1973,
#   'slide forward on your right foot while kicking with your left foot'],
#  [9677.923828125,
#   [0.3496503531932831, 0.03296703100204468],
#   1032,
#   'run forward on your left foot while lifting your right foot'],
#  [9660.9755859375,
#   [0.35464534163475037, 0.025974025949835777],
#   1060,
#   'run forward on left foot while lifting right foot'],
#  [9644.4208984375,
#   [0.5884115695953369, 0.04695304483175278],
#   1193,
#   'hop forward on left foot while lifting right foot'],
#  [9672.56640625,
#   [0.3526473343372345, 0.025974025949835777],
#   1010,
#   'hop forward on left foot while lifting right foot'],
#  [9665.056640625,
#   [0.3416583240032196, 0.02997002936899662],
#   1061,
#   'hop forward on your left foot while lifting your right foot'],
#  [9697.21484375,
#   [0.35764235258102417, 0.02997002936899662],
#   1034,
#   'run forward on your left foot while lifting your right foot'],
#  [9696.3916015625,
#   [0.5414585471153259, 0.05394605174660683],
#   1206,
#   'shuffle forward on your left foot while lifting your right foot'],
#  [9656.46875,
#   [0.14985014498233795, 0.5074924826622009],
#   3823,
#   'slide forward on your right foot while kicking with your left foot'],
#  [9685.4375,
#   [0.3526473343372345, 0.021978020668029785],
#   1037,
#   'run forward on your left foot while lifting your right foot'],
#  [7058.169921875,
#   [0.9240759015083313, 0.25674325227737427],
#   6594,
#   'slowly shuffle forward while tapping right foot on ground'],
#  [9516.40234375,
#   [0.8901098370552063, 0.09390608966350555],
#   1278,
#   'shuffle forward on left foot while lifting right foot off the ground'],
#  [9686.59765625,
#   [0.5094904899597168, 0.06493506580591202],
#   1134,
#   'hop forward on left foot while lifting right foot off the ground'],
#  [9687.396484375,
#   [0.5314685106277466, 0.0559440553188324],
#   1133,
#   'hop forward on left foot while lifting your right foot'],
#  [9665.6376953125,
#   [0.5524475574493408, 0.042957041412591934],
#   1135,
#   'hop forward on your left foot while lifting your right foot']]
